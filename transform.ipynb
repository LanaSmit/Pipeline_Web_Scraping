# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\lana\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lana\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lana\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lana\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lana\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lana\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import polars as pl
# Could have use polars
df = pl.read_csv("netflix_top10.csv")
df.head()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────┬──────────┬─────────┬──────────────┐
# │ Title                       ┆ Views    ┆ Runtime ┆ Hours Viewed │
# │ ---                         ┆ ---      ┆ ---     ┆ ---          │
# │ str                         ┆ i64      ┆ str     ┆ i64          │
# ╞═════════════════════════════╪══════════╪═════════╪══════════════╡
# │ 01The Woman in Cabin 10     ┆ 30100000 ┆ 1:35    ┆ 47700000     │
# │ 02The Perfect Neighbor      ┆ 16700000 ┆ 1:39    ┆ 27500000     │
# │ 03KPop Demon Hunters        ┆ 16200000 ┆ 1:40    ┆ 27000000     │
# │ 04My Father, the BTK Killer ┆ 6400000  ┆ 1:34    ┆ 10100000     │
# │ 05The Twits                 ┆ 5900000  ┆ 1:43    ┆ 10200000     │
# └─────────────────────────────┴──────────┴─────────┴──────────────┘

# %%
#normalize the column names
df.columns = [col.lower().replace(" ","_") for col in df.columns]

# %%
#remove the numbers from the "title" column
df = df.with_columns(
    pl.col("title").str.replace(r"^\d+", "").alias("title")
)

# %%
df.head()
# Out:
# shape: (5, 4)
# ┌───────────────────────────┬──────────┬─────────┬──────────────┐
# │ title                     ┆ views    ┆ runtime ┆ hours_viewed │
# │ ---                       ┆ ---      ┆ ---     ┆ ---          │
# │ str                       ┆ i64      ┆ str     ┆ i64          │
# ╞═══════════════════════════╪══════════╪═════════╪══════════════╡
# │ The Woman in Cabin 10     ┆ 30100000 ┆ 1:35    ┆ 47700000     │
# │ The Perfect Neighbor      ┆ 16700000 ┆ 1:39    ┆ 27500000     │
# │ KPop Demon Hunters        ┆ 16200000 ┆ 1:40    ┆ 27000000     │
# │ My Father, the BTK Killer ┆ 6400000  ┆ 1:34    ┆ 10100000     │
# │ The Twits                 ┆ 5900000  ┆ 1:43    ┆ 10200000     │
# └───────────────────────────┴──────────┴─────────┴──────────────┘
